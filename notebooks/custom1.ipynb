# %% [markdown]
# <a href="https://colab.research.google.com/github/SeverinSchmidt/brax/blob/main/notebooks/custom1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import functools
import time

from IPython.display import HTML, Image 
import gym

from IPython.display import clear_output 
# !pip install git+https://github.com/SeverinSchmidt/brax.git@main
clear_output()
import brax

from brax import envs
from brax import jumpy as jp
from brax.envs import to_torch
from brax.io import html
from brax.io import image
import jax
from jax import numpy as jnp
import torch
v = torch.ones(1, device='cuda')  # init torch cuda before jax
# Out:
# /usr/local/lib/python3.9/dist-packages/trimesh/curvature.py:12: DeprecationWarning: Please use `coo_matrix` from the `scipy.sparse` namespace, the `scipy.sparse.coo` namespace is deprecated.
#   from scipy.sparse.coo import coo_matrix
# /usr/local/lib/python3.9/dist-packages/jax/_src/deprecations.py:51: DeprecationWarning: jax.interpreters.xla.DeviceArray is deprecated. Use jax.Array instead.
#   warnings.warn(message, DeprecationWarning)

# %%
environment = "humanoid"  # @param ['ant', 'halfcheetah', 'hopper', 'humanoid', 'reacher', 'walker2d', 'fetch', 'grasp', 'ur5e']
env = envs.create(env_name=environment)
state = env.reset(rng=jp.random_prngkey(seed=0))



config = env.sys.config.bodies
#Changing coordiantes of the ball
config[-1].frozen.position.x,config[-1].frozen.position.y = 3,5000
config[-1].colliders[0].sphere.radius = 0.5
config[-1].colliders[0]
print(config[-1])
# Out:
# name: "Target"
# colliders {
#   position {
#     x: 5.0
#     y: 5.0
#     z: 5.0
#   }
#   sphere {
#     radius: 0.5
#   }
#   material {
#     friction: 1.0
#   }
# }
# inertia {
#   x: 1.0
#   y: 1.0
#   z: 1.0
# }
# frozen {
#   position {
#     x: 3.0
#     y: 5000.0
#     z: 1.0
#   }
#   rotation {
#     x: 1.0
#     y: 1.0
#     z: 1.0
#   }
#   all: true
# }

# %%
HTML(html.render(env.sys, [state.qp]))
# Out:
# <html>
#   <head>
#     <title>brax visualizer</title>
#     <style>
#       body {
#         margin: 0;
#         padding: 0;
#       }
#       #brax-viewer {
#         margin: 0;
#         padding: 0;
#         height: 480px;
#       }
#     </style>
#   </head>
#   <body>
#     <script type="application/javascript">
# ...

# %%
envs
# Out:
# <module 'brax.envs' from '/usr/local/lib/python3.9/dist-packages/brax/envs/__init__.py'>

# %%
# %%time
rollout = []
for i in range(100):
  # wiggle sinusoidally with a phase shift per actuator
  action = jp.sin(i * jp.pi / 15 + jp.arange(0, env.action_size) * jp.pi)
  state = env.step(state, action)
  rollout.append(state)
# Out:
# CPU times: user 58.3 s, sys: 967 ms, total: 59.2 s
# Wall time: 1min 2s

# %%
print(config[-1])
HTML(html.render(env.sys, [s.qp for s in rollout]))
# Out:
# name: "Target"
# colliders {
#   position {
#     x: 5.0
#     y: 5.0
#     z: 5.0
#   }
#   sphere {
#     radius: 0.5
#   }
#   material {
#     friction: 1.0
#   }
# }
# inertia {
#   x: 1.0
#   y: 1.0
#   z: 1.0
# }
# frozen {
#   position {
#     x: 3.0
#     y: 5000.0
#     z: 1.0
#   }
#   rotation {
#     x: 1.0
#     y: 1.0
#     z: 1.0
#   }
#   all: true
# }
# <html>
#   <head>
#     <title>brax visualizer</title>
#     <style>
#       body {
#         margin: 0;
#         padding: 0;
#       }
#       #brax-viewer {
#         margin: 0;
#         padding: 0;
#         height: 480px;
#       }
#     </style>
#   </head>
#   <body>
#     <script type="application/javascript">
# ...

# %%
environment = "pusher"  # @param ['ant', 'halfcheetah', 'hopper', 'humanoid', 'reacher', 'walker2d', 'fetch', 'grasp', 'ur5e']
env = envs.create(env_name=environment)
state = env.reset(rng=jp.random_prngkey(seed=0))

# %%
HTML(html.render(env.sys, [state.qp]))
# Out:
# <html>
#   <head>
#     <title>brax visualizer</title>
#     <style>
#       body {
#         margin: 0;
#         padding: 0;
#       }
#       #brax-viewer {
#         margin: 0;
#         padding: 0;
#         height: 480px;
#       }
#     </style>
#   </head>
#   <body>
#     <script type="application/javascript">
# ...

# %%
with open("/content/humanoid.xml") as file:
  xml = file.readlines()[15:]

# %%
xml_string = ''
for line in xml:
  xml_string += line
xml_string

# %%
# Read the Mujoco model.
xml_model_path = '/content/humanoid.xml'
filename = FLAGS.xml_model_path
with file.File(filename) as f:
  logging.info('Loading mujoco model from %s', filename)
  xml_string = f.read()

# %%
# !pip install dm_control
# !pip install transforms3d
#from brax.tools import mujoco
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 17.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 67.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.6/207.6 KB 7.6 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for transforms3d: filename=transforms3d-0.4.1-py3-none-any.whl size=1376772 sha256=63ba65873ab49617149294fd749967206aa180356d9201f6a75ee737495810bd
#   Stored in directory: /root/.cache/pip/wheels/a5/2d/e4/5d7de7a69ab4e6301b3125441725d47fe25b9e60e7d670ad21
# Successfully built transforms3d
# ...

# %%
converter = mujoco.MujocoConverter(xml_string)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-383abc4e0d85> in <module>
# ----> 1 converter = mujoco.MujocoConverter(xml_string)
#
# /usr/local/lib/python3.9/dist-packages/brax/tools/mujoco.py in __init__(self, xml_string, add_collision_pairs, ignore_unsupported_joints, add_joint_to_nearest_body)
#     207     # Worldbody is the root of the scene tree. We add the bodies starting from
#     208     # the world body in a depth-first manner.
# --> 209     self._add_body(mjcf_model.worldbody, None)
#     210     # Add the actuators and the collision pairs.
#     211     self._add_actuators()
#
# /usr/local/lib/python3.9/dist-packages/brax/tools/mujoco.py in _add_body(self, mujoco_body, parent_body)
#     417
#     418     for child_mujoco_body in mujoco_body.body:
# --> 419       self._add_body(child_mujoco_body, body)
#     420
# ...

# %%
# !python
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `python print("x")'
